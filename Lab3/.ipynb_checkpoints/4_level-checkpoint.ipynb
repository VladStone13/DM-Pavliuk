# %% [markdown]
# ## ЕЛЕМЕНТИ DATA CLEANING

# %% [markdown]
# ### ВАРІАНТ № 4
# ### Загальні положення

# %% [markdown]
# __Мета__:
# - Опанувати деякі методи завантаження, видобутоку та очищення первинних даних
# - Застосувати на практиці набуті знання та навички програмування на Python, а саме:
#     - читання і запис даних у файли;
#     - організація циклічної оброобки даних (for .. in ..)
#     - реалізація умовної обробки (if .. elif .. else)
#     - використання методів і функцій стандартної бібліотеки Python
#
# __Вхідні дані__ : файл __aprts_data_raw.csv__, якій отримано з ресурсу _https://flatfy.lun.ua/продажа-квартир-киев_ шляхом його парсингу.
#
# Файл має наступну структуру:
#
# |    | Назва поля      | Очікуваний формат поля   |
# | -- | :-----------     | :-------------------------|
# |  1 | Ціна квартири (\$ або грн)    | дробове                  |
# |  2 | Кількість кімнат | ціле
# |  3 | Ціна за м² (\$ або грн)     | дробове
# |  4 | Поверх та всього поверхів | ціле
# | 5  | рік побудови   | ціле
# | 6  | тип будинку    | текст
# | 7  | Площа (загальна/житлова/кухні)| дробове
# | 8  | вулиця         | текст
# | 9  | номер дому     | текст
#
# __Особливі умови__: в первиних даних деякі показники можуть бути відстутні (не распарсені) - тоді вони позначаються `*** not found`

# %% [markdown]
# ### Теоретична частина та приклади

# %% [markdown]
# Вхідний файл треба зчитувати і обробляти __порядково__ -  це гарна практика роботи з великими об\`ємами даних.
#
# Дані, що зчитуються з файлів порядково представляються у текстовому (__str__) форматі, тому доцільно використовувати [функції обробки строкових даних](https://pythonworld.ru/tipy-dannyx-v-python/stroki-funkcii-i-metody-strok.html) python:

# %%
# split() - дозволяє розділити текстову строку на окремі поля і помістити їх в список

stroka = "Вася Пупкін - студент 5 курсу ФІТ"
print("Розподільник: ` `")
print (stroka)
list_from_stroka = stroka.split()
print(list_from_stroka, end='\n\n')

# якщо в якості аргумента split вказати розподільник, 
# то він буде використаний при побудові списка
list_from_stroka = stroka.split('-')
print("Розподільник: `-`")
print (stroka)
print(list_from_stroka)

# %% [markdown]
# __Примітка:__ файли в csv-форматі мають в якості розподільника, як правило, символ `,`

# %%
# за допомогою метода strip() є можливість "обрізати" зліва та справа пробіли 
# (якщо параметер не вказано), або символи, які вказані в якостиі параметрів:

stroka = "     Вася Пупкін - студент 5 курсу ФІТ   "
striped_stroka = stroka.strip()
print(stroka)
print(striped_stroka)
print(striped_stroka.strip('ФІТ'))

# %% [markdown]
# __Конвертування строкових даних__ у чисельні здійснюється за допомогою функцій [int](https://pythoner.name/int-function) або [float](https://www.programiz.com/python-programming/methods/built-in/float), але треба мати на увазі що ці функціі викинуть виключення, якщо буде спроба конвертувати не число. Тому перед виконанням конвертування доцільно перевіряти, чи буде воно успішнім. Для цього можна викорастати функцію [isnumeric](https://pythonz.net/references/named/str.isnumeric/).

# %%
# 
number_str = '123.3'
print(type(number_str))
number_float = float(number_str)
print(type(number_float), end='\n\n')

# але
maybe_number_str = '123.З' # після крапки не число!
print(type(number_str))
# number_float = float(maybe_number_str) # ValueError: could not convert string to float: '123.З'

# треба
if maybe_number_str.isnumeric():
    #  True
    number_float = float(maybe_number_str)
else:
    # False
    # код який обробляє цю ситуацію
    ...

# %% [markdown]
# ### Приклад розбору рядків, та вилучення показчиків

# %%
# Припустимо, що ми маємо файл, вміст якого відображається на список:
file_content = [
    'Вася Пупкін ,  5 курс, ФІТ',
    'Петя Сидоров, 1 курс, ФТМ',
    ' Вова   Хлопов , 3 курс, ФІТ'
]
_ = [print(x) for x in file_content]

# %%
# треба створити новий список, який буде містити окремо ім'я та прізвище

# зарезервуєм пустий контейнер
name_and_surname = []

for line in file_content:
    list_from_line = line.split(',')
    name, surname = list_from_line[0].split()
    name_and_surname += [[name.strip(), surname.strip()]]

_ = [print(x) for x in name_and_surname]

# %%
# теж саме в функціональному стилі 
from functools import reduce
reduce(lambda acc, line: acc + [line.split(',')[0].split()], file_content, [])

# %% [markdown]
# ### ЗАВДАННЯ
#
# <p style="background-color: lightblue; padding:10px">На основі вхідного файлу <b>aprts_data_raw.csv</b> побудувати вихідний файл <b>aprt_level.txt</b> кожний рядок якого є вилучене з 4 показника та приведене до очікуваного формату значення поверху на якому розташована квартира.<br><br><i>При неможливості приведення показчика його треба замінити на 0</i></p>

# %% [markdown]
# _Фрагмент_ результатного файлу:
#
# `
# 21
# 11
# 5
# 5
# ...
# `

# %%
# Ваш код повинен починатися тут
import pandas as pd

spreadsheet = pd.read_csv('aprts_data_raw.csv', header = None)

with open('aprt_level.txt', 'w') as f:
    for row in spreadsheet.iloc[:, 3]:        
        line = row.split() 
        if(line[0] == "***"):
            f.write("0" + "\n")
            
        elif(line[len(line) - 1] == "дом"):
            floor = line[0].split('-')
            f.write(str(floor[0]) + "\n")
            
        else:
             f.write(str(line[0])  + "\n")

# %%
spreadsheet
# Out:
#                   0               1                 2               3  \
# 0         115 000 $       2 комнаты      1575 $ за м²        21 из 25
# 1          75 000 $       3 комнаты       680 $ за м²        11 из 25
# 2         140 000 $       3 комнаты      1400 $ за м²         5 из 18
# 3         140 000 $       2 комнаты      2414 $ за м²          5 из 5
# 4         160 000 $       2 комнаты      2025 $ за м²         2 из 10
# 5         870 000 $       3 комнаты      6273 $ за м²         2 из 22
# 6    14 883 863 грн        5 комнат  73 902 грн за м²        21 из 23
# 7         220 000 $       2 комнаты      2529 $ за м²         4 из 23
# 8         133 000 $       1 комната      3325 $ за м²         6 из 20
# 9          69 000 $       2 комнаты      1353 $ за м²          2 из 9
# 10        169 999 $       1 комната      3542 $ за м²         8 из 19
# 11        212 000 $       2 комнаты      2494 $ за м²         2 из 17
# 12         83 500 $       2 комнаты      1099 $ за м²        13 из 25
# 13         75 000 $       2 комнаты      1339 $ за м²        12 из 12
# 14         65 000 $       1 комната      1711 $ за м²        12 из 25
# 15         82 000 $       3 комнаты      1171 $ за м²          5 из 9
# 16        207 000 $       3 комнаты      2010 $ за м²        16 из 18
# 17         51 990 $       2 комнаты       921 $ за м²          4 из 6
# 18         57 999 $       3 комнаты       841 $ за м²         3 из 10
# 19         57 000 $       2 комнаты      1203 $ за м²        21 из 24
# 20         95 000 $       1 комната      1900 $ за м²         3 из 23
# 21         50 000 $       3 комнаты       781 $ за м²          8 из 9
# 22         95 000 $       4 комнаты       990 $ за м²          5 из 5
# 23         46 860 $       2 комнаты      1019 $ за м²          5 из 5
# 24         38 500 $       2 комнаты       875 $ за м²          3 из 5
# 25        110 000 $       3 комнаты      1100 $ за м²         7 из 12
# 26        269 000 $        5 комнат      1121 $ за м²        14 из 15
# 27    1 983 000 грн       2 комнаты  27 503 грн за м²         6 из 25
# 28        119 000 $       2 комнаты      1587 $ за м²        19 из 25
# 29        210 000 $       3 комнаты      2692 $ за м²          1 из 5
# 30        310 000 $       3 комнаты      2460 $ за м²         7 из 16
# 31         93 000 $       3 комнаты      1000 $ за м²        12 из 18
# 32         98 000 $       2 комнаты      1556 $ за м²         6 из 16
# 33         78 000 $       2 комнаты      1773 $ за м²          1 из 4
# 34         68 000 $       2 комнаты      1001 $ за м²        24 из 26
# 35         77 000 $       1 комната      1481 $ за м²        11 из 17
# 36        176 000 $       3 комнаты      1778 $ за м²         5 из 25
# 37    5 572 000 грн       3 комнаты  58 042 грн за м²         9 из 12
# 38        129 000 $       3 комнаты      1985 $ за м²          3 из 4
# 39        136 000 $       2 комнаты      2720 $ за м²        15 из 25
# 40         71 000 $       3 комнаты       934 $ за м²          3 из 9
# 41        108 000 $       1 комната      2384 $ за м²        15 из 25
# 42        175 000 $       4 комнаты      1768 $ за м²          9 из 9
# 43         45 006 $       3 комнаты       602 $ за м²        17 из 17
# 44         78 000 $       2 комнаты      1322 $ за м²        22 из 25
# 45         65 000 $       3 комнаты       890 $ за м²          1 из 9
# 46    3 396 000 грн       2 комнаты  54 774 грн за м²        14 из 25
# 47         68 899 $       3 комнаты       907 $ за м²          5 из 5
# 48        205 000 $       2 комнаты      2697 $ за м²        12 из 23
# 49        211 000 $       3 комнаты      1005 $ за м²   4-этажный дом
# 50         36 500 $       1 комната      1106 $ за м²          5 из 5
# 51    3 176 715 грн       1 комната  47 556 грн за м²        16 из 26
# 52        155 000 $       2 комнаты      2500 $ за м²        14 из 24
# 53        109 000 $       3 комнаты      1068 $ за м²        13 из 25
# 54        120 000 $       3 комнаты      1091 $ за м²         3 из 16
# 55         55 000 $       2 комнаты      1078 $ за м²        10 из 10
# 56         48 000 $       2 комнаты      1091 $ за м²          7 из 9
# 57        235 000 $       2 комнаты      2582 $ за м²         6 из 24
# 58         41 000 $       1 комната      1464 $ за м²          9 из 9
# 59        143 000 $       1 комната      2554 $ за м²        10 из 11
# 60         65 000 $       3 комнаты       966 $ за м²          9 из 9
# 61        500 000 $       3 комнаты      5000 $ за м²          2 из 5
# 62         94 000 $       3 комнаты      1146 $ за м²          3 из 5
# 63        280 000 $       3 комнаты      2295 $ за м²         3 из 24
# 64         67 500 $       1 комната      1500 $ за м²          5 из 9
# 65         72 000 $       2 комнаты       960 $ за м²  *** not found
# 66         54 000 $       1 комната      1588 $ за м²        29 из 33
# 67         74 000 $       2 комнаты      1609 $ за м²          2 из 8
# 68        130 000 $       2 комнаты      1300 $ за м²        16 из 24
# 69        110 000 $       3 комнаты      1111 $ за м²         4 из 25
# 70        180 000 $       3 комнаты      2400 $ за м²          3 из 8
# 71         69 000 $       2 комнаты      1113 $ за м²        21 из 25
# 72        205 000 $       2 комнаты      2697 $ за м²        12 из 23
# 73        211 000 $       3 комнаты      1005 $ за м²   4-этажный дом
# 74         36 500 $       1 комната      1106 $ за м²          5 из 5
# 75    3 176 715 грн       1 комната  47 556 грн за м²        16 из 26
# 76        155 000 $       2 комнаты      2500 $ за м²        14 из 24
# 77        109 000 $       3 комнаты      1068 $ за м²        13 из 25
# 78        120 000 $       3 комнаты      1091 $ за м²         3 из 16
# 79         55 000 $       2 комнаты      1078 $ за м²        10 из 10
# 80         48 000 $       2 комнаты      1091 $ за м²          7 из 9
# 81        235 000 $       2 комнаты      2582 $ за м²         6 из 24
# 82         41 000 $       1 комната      1464 $ за м²          9 из 9
# 83        143 000 $       1 комната      2554 $ за м²        10 из 11
# 84         65 000 $       3 комнаты       966 $ за м²          9 из 9
# 85        500 000 $       3 комнаты      5000 $ за м²          2 из 5
# 86         94 000 $       3 комнаты      1146 $ за м²          3 из 5
# 87        280 000 $       3 комнаты      2295 $ за м²         3 из 24
# 88         67 500 $       1 комната      1500 $ за м²          5 из 9
# 89         72 000 $       2 комнаты       960 $ за м²  *** not found
# 90         54 000 $       1 комната      1588 $ за м²        29 из 33
# 91         74 000 $       2 комнаты      1609 $ за м²          2 из 8
# 92        130 000 $       2 комнаты      1300 $ за м²        16 из 24
# 93        110 000 $       3 комнаты      1111 $ за м²         4 из 25
# 94        180 000 $       3 комнаты      2400 $ за м²          3 из 8
# 95         69 000 $       2 комнаты      1113 $ за м²        21 из 25
# 96        120 000 $       3 комнаты      1667 $ за м²          6 из 6
# 97        150 000 $       3 комнаты      1290 $ за м²         7 из 22
# 98        750 000 $       4 комнаты      4717 $ за м²              10
# 99         75 000 $       3 комнаты       987 $ за м²          2 из 5
# 100        53 000 $       1 комната      1120 $ за м²         5 из 16
# 101        42 500 $       2 комнаты       966 $ за м²          2 из 5
# 102       103 000 $       3 комнаты      1084 $ за м²         2 из 13
# 103       650 000 $        5 комнат      2708 $ за м²        23 из 23
# 104        56 000 $       1 комната      1556 $ за м²         2 из 15
# 105        90 000 $       1 комната      1800 $ за м²         7 из 25
# 106        77 000 $       2 комнаты      1085 $ за м²        11 из 16
# 107       115 000 $       2 комнаты      1901 $ за м²          4 из 5
# 108       120 000 $       2 комнаты      1488 $ за м²         6 из 22
# 109       130 000 $       3 комнаты      1057 $ за м²         9 из 27
# 110        85 000 $       2 комнаты      1149 $ за м²         4 из 22
# 111       140 000 $       2 комнаты      1728 $ за м²        18 из 25
# 112        45 500 $       1 комната      1058 $ за м²         5 из 25
# 113        63 232 $       3 комнаты       753 $ за м²         3 из 18
# 114        95 000 $       2 комнаты      2065 $ за м²         3 из 24
# 115        55 000 $       1 комната      1000 $ за м²         5 из 24
# 116       186 900 $       3 комнаты      1374 $ за м²        23 из 25
# 117        34 200 $       1 комната      1605 $ за м²         3 из 28
# 118       234 899 $       3 комнаты      1727 $ за м²          8 из 9
# 119        55 000 $       1 комната      1341 $ за м²         9 из 25
# 120       136 000 $       2 комнаты      1915 $ за м²         3 из 10
# 121       139 000 $       2 комнаты      2439 $ за м²          3 из 6
# 122       210 000 $       3 комнаты      1409 $ за м²         7 из 12
# 123       195 000 $       1 комната      3900 $ за м²         5 из 16
# 124       119 000 $       3 комнаты      1587 $ за м²         3 из 25
# 125       410 000 $       3 комнаты      4457 $ за м²        11 из 26
# 126        93 000 $       2 комнаты      1550 $ за м²        17 из 22
# 127       137 634 $       2 комнаты      1939 $ за м²        19 из 19
# 128       115 000 $       2 комнаты      1901 $ за м²          4 из 5
# 129        85 000 $       1 комната      1545 $ за м²        19 из 25
# 130       130 000 $       3 комнаты      1566 $ за м²         6 из 10
# 131       113 000 $       1 комната      2055 $ за м²         4 из 20
# 132        39 500 $       1 комната      1097 $ за м²        23 из 25
# 133        68 000 $       3 комнаты      1046 $ за м²          9 из 9
# 134       155 000 $       3 комнаты      1384 $ за м²         3 из 25
# 135       110 000 $       2 комнаты      2200 $ за м²          3 из 3
# 136        75 000 $       2 комнаты      1103 $ за м²        12 из 24
# 137       142 000 $       3 комнаты      1671 $ за м²         2 из 15
# 138        80 000 $       2 комнаты      1569 $ за м²          6 из 9
# 139        43 000 $       2 комнаты       935 $ за м²          4 из 4
# 140       248 000 $        5 комнат      1198 $ за м²        10 из 14
# 141       280 000 $       3 комнаты      2154 $ за м²         8 из 11
# 142       209 000 $       2 комнаты      2580 $ за м²         2 из 10
# 143        58 990 $       1 комната      1439 $ за м²         3 из 32
# 144       111 000 $       1 комната      2220 $ за м²        23 из 25
# 145        97 000 $       3 комнаты      1796 $ за м²          2 из 9
# 146        68 000 $       3 комнаты       819 $ за м²         7 из 25
# 147       184 900 $       3 комнаты      2283 $ за м²         3 из 13
# 148        61 500 $       2 комнаты      1398 $ за м²          3 из 5
# 149       111 000 $       3 комнаты      1233 $ за м²         2 из 25
# 150       190 700 $       2 комнаты      2414 $ за м²        11 из 11
# 151        53 000 $       1 комната      1233 $ за м²        21 из 24
# 152        69 000 $       2 комнаты      1353 $ за м²          2 из 9
# 153       169 000 $       4 комнаты      1340 $ за м²          7 из 8
# 154        95 000 $       2 комнаты      1730 $ за м²        10 из 16
# 155       110 000 $       3 комнаты      1000 $ за м²        13 из 18
# 156   5 880 000 грн        5 комнат  55 472 грн за м²        22 из 25
# 157        99 999 $       3 комнаты      1389 $ за м²         5 из 22
# 158       327 000 $       4 комнаты      2680 $ за м²        17 из 20
# 159        85 000 $       2 комнаты      1269 $ за м²        13 из 34
# 160       790 000 $        6 комнат      2894 $ за м²          6 из 6
# 161        95 000 $       3 комнаты      1145 $ за м²        11 из 16
# 162        70 000 $       1 комната      1556 $ за м²         9 из 16
# 163   2 352 122 грн       3 комнаты  31 530 грн за м²          1 из 4
# 164     807 000 грн       1 комната  30 000 грн за м²          1 из 5
# 165        77 000 $       1 комната      1571 $ за м²        17 из 26
# 166        75 000 $       2 комнаты       892 $ за м²        11 из 11
# 167       480 000 $       4 комнаты      2623 $ за м²          4 из 5
# 168        70 000 $       1 комната      1449 $ за м²        10 из 24
# 169       205 000 $       2 комнаты      2697 $ за м²        12 из 23
# 170       499 990 $       3 комнаты      3125 $ за м²         5 из 11
# 171        52 000 $       1 комната      1274 $ за м²         5 из 16
# 172        93 000 $       1 комната      1563 $ за м²         7 из 14
# 173       117 000 $       3 комнаты      1603 $ за м²         9 из 16
# 174        53 900 $       1 комната      1152 $ за м²        23 из 25
# 175        58 000 $       1 комната      1318 $ за м²        15 из 24
# 176       159 000 $       2 комнаты      2120 $ за м²        12 из 25
# 177       116 000 $       2 комнаты      1933 $ за м²        22 из 26
# 178        42 000 $       1 комната      1235 $ за м²          6 из 9
# 179        55 500 $       3 комнаты       854 $ за м²          6 из 9
# 180       370 000 $       3 комнаты      1947 $ за м²         5 из 24
# 181       650 000 $       4 комнаты      2708 $ за м²          8 из 8
# 182       355 000 $       3 комнаты      4176 $ за м²  *** not found
# 183       145 000 $       1 комната      3021 $ за м²         2 из 24
# 184       117 000 $       2 комнаты      1560 $ за м²         2 из 25
# 185       300 000 $       2 комнаты      5000 $ за м²          1 из 6
# 186        55 000 $       1 комната      1107 $ за м²         7 из 22
# 187        41 000 $       2 комнаты       869 $ за м²          2 из 5
# 188       128 000 $       2 комнаты      2560 $ за м²         3 из 25
# 189       175 000 $       2 комнаты      2465 $ за м²         2 из 25
# 190     783 000 грн       1 комната  25 808 грн за м²          3 из 5
# 191        90 000 $       2 комнаты      1324 $ за м²        23 из 25
# 192        98 000 $       2 комнаты      2227 $ за м²          3 из 5
# 193       137 000 $       1 комната      2854 $ за м²        15 из 23
# 194        45 000 $       1 комната       978 $ за м²         7 из 26
# 195   2 015 228 грн       2 комнаты  31 537 грн за м²        19 из 26
# 196       200 000 $       3 комнаты      2163 $ за м²          3 из 5
# 197       147 000 $       2 комнаты      2333 $ за м²         9 из 24
# 198        78 000 $       3 комнаты      1099 $ за м²          5 из 9
# 199        82 000 $       1 комната      2343 $ за м²        15 из 15
# 200        75 000 $       1 комната      1562 $ за м²          4 из 6
# 201        89 000 $       1 комната      1589 $ за м²        15 из 20
# 202       710 000 $       4 комнаты      3447 $ за м²         7 из 25
# 203       620 000 $        5 комнат      3605 $ за м²        14 из 17
# 204        69 500 $       3 комнаты      1544 $ за м²          1 из 7
# 205        85 000 $       2 комнаты      1000 $ за м²         8 из 25
# 206        43 000 $       2 комнаты       878 $ за м²          6 из 6
# 207       330 000 $       4 комнаты      1710 $ за м²        16 из 16
# 208        59 000 $       2 комнаты      1429 $ за м²          2 из 9
# 209        40 000 $       3 комнаты       930 $ за м²          1 из 5
# 210     1 200 000 $        5 комнат      3429 $ за м²          4 из 6
# 211       405 000 $       3 комнаты      3189 $ за м²        20 из 31
# 212       100 110 $       3 комнаты      1285 $ за м²         4 из 16
# 213       400 000 $       4 комнаты      2222 $ за м²        12 из 25
# 214        97 500 $       1 комната      1788 $ за м²        16 из 26
# 215        83 000 $  *** not found     *** not found   *** not found
# 216        44 000 $       3 комнаты       733 $ за м²          2 из 5
# 217        66 000 $       3 комнаты      1100 $ за м²          8 из 9
# 218       350 000 $       4 комнаты      2011 $ за м²         2 из 10
# 219        77 000 $       2 комнаты      1055 $ за м²        15 из 25
# 220       122 250 $       3 комнаты      1315 $ за м²        22 из 24
# 221        65 000 $       3 комнаты       888 $ за м²          6 из 9
# 222       170 000 $       4 комнаты      1214 $ за м²         4 из 16
# 223        95 000 $       1 комната      1900 $ за м²        13 из 25
# 224        85 000 $       3 комнаты       966 $ за м²         3 из 16
# 225        69 500 $       1 комната      1454 $ за м²        25 из 25
# 226       152 000 $       2 комнаты      3535 $ за м²         9 из 24
# 227        92 000 $       3 комнаты      1278 $ за м²          6 из 9
# 228       375 000 $        6 комнат      1518 $ за м²        27 из 27
# 229       449 000 $        5 комнат      1796 $ за м²        12 из 16
# 230        75 500 $       2 комнаты      1127 $ за м²         9 из 25
# 231       140 000 $       2 комнаты      1728 $ за м²          9 из 9
# 232        45 000 $       1 комната      1364 $ за м²  *** not found
# 233       135 000 $       1 комната      2316 $ за м²        11 из 15
# 234       125 000 $       4 комнаты      1344 $ за м²        26 из 33
# 235       140 000 $       3 комнаты      1284 $ за м²        21 из 25
# 236       120 000 $       2 комнаты      1713 $ за м²        14 из 16
# 237        42 000 $       2 комнаты       764 $ за м²          1 из 5
# 238       125 000 $       3 комнаты      1420 $ за м²         3 из 24
# 239        48 000 $       2 комнаты      1086 $ за м²          4 из 5
# 240       300 000 $       3 комнаты      2000 $ за м²        16 из 17
# 241       120 000 $       3 комнаты      1379 $ за м²        20 из 24
# 242       649 000 $        5 комнат      2360 $ за м²        11 из 17
# 243        64 980 $       4 комнаты       812 $ за м²          4 из 9
# 244        77 000 $       1 комната      1426 $ за м²        16 из 24
# 245        48 000 $       1 комната      1116 $ за м²        24 из 26
# 246       102 000 $       3 комнаты      1085 $ за м²         2 из 22
# 247       185 000 $       1 комната      4405 $ за м²        22 из 24
# 248        42 000 $       1 комната      1243 $ за м²        10 из 22
# 249       115 000 $       3 комнаты       991 $ за м²        16 из 19
# 250       175 000 $       2 комнаты      2303 $ за м²         4 из 14
# 251        54 000 $       3 комнаты       915 $ за м²          9 из 9
# 252  10 116 000 грн       4 комнаты  50 580 грн за м²        12 из 12
# 253       137 000 $       2 комнаты      1957 $ за м²        18 из 24
# 254        95 000 $       3 комнаты      1258 $ за м²        12 из 20
# 255       360 000 $        5 комнат      2400 $ за м²          5 из 6
# 256       135 000 $       1 комната       833 $ за м²         6 из 16
# 257       105 000 $       1 комната      2333 $ за м²          1 из 9
# 258        58 000 $       2 комнаты       935 $ за м²         4 из 26
# 259       180 000 $        5 комнат      2400 $ за м²          3 из 4
# 260       153 000 $       2 комнаты      1692 $ за м²         8 из 27
# 261       159 000 $       2 комнаты      2271 $ за м²         6 из 12
# 262        98 000 $       3 комнаты      1032 $ за м²         6 из 25
# 263     1 200 000 $  *** not found       2162 $ за м²        25 из 25
# 264        42 900 $       1 комната      1140 $ за м²        11 из 26
# 265        86 000 $       3 комнаты       925 $ за м²          6 из 8
# 266       155 000 $       1 комната      2818 $ за м²         5 из 19
# 267       450 000 $       3 комнаты      4412 $ за м²        15 из 30
# 268       148 000 $       3 комнаты      1574 $ за м²  *** not found
# 269        50 000 $       1 комната      1220 $ за м²          4 из 5
# 270        81 000 $       3 комнаты      1045 $ за м²         5 из 26
# 271       161 003 $       3 комнаты      1830 $ за м²         5 из 23
# 272        61 500 $       2 комнаты       933 $ за м²        20 из 26
# 273        78 000 $       2 комнаты      1164 $ за м²        13 из 24
# 274       259 266 $       3 комнаты      2038 $ за м²          7 из 9
# 275        34 500 $       1 комната      1113 $ за м²          5 из 9
# 276       122 000 $       3 комнаты      1402 $ за м²        21 из 22
# 277       147 420 $       2 комнаты      1798 $ за м²        21 из 25
# 278        73 000 $       2 комнаты      1460 $ за м²          1 из 9
# 279        44 000 $       1 комната      1100 $ за м²        11 из 26
# 280       128 000 $       3 комнаты      1829 $ за м²          2 из 4
# 281       111 000 $       1 комната      1480 $ за м²         2 из 10
# 282        73 000 $       3 комнаты       760 $ за м²         9 из 20
# 283        89 000 $       1 комната      1589 $ за м²        15 из 20
# 284        64 000 $       1 комната      1488 $ за м²        14 из 25
# 285       375 000 $       3 комнаты      3151 $ за м²  *** not found
# 286        98 000 $       1 комната      2279 $ за м²          4 из 4
# 287        32 000 $       1 комната      1455 $ за м²          8 из 9
# 288       125 000 $       3 комнаты      1190 $ за м²        16 из 24
# 289        61 500 $       2 комнаты      1398 $ за м²          3 из 5
# 290       105 000 $       2 комнаты      1522 $ за м²        16 из 25
# 291   2 425 640 грн       1 комната    *** not found   *** not found
# 292        89 000 $       3 комнаты       937 $ за м²         9 из 13
# 293        27 500 $       1 комната       982 $ за м²          9 из 9
# 294        47 000 $       1 комната      1175 $ за м²         5 из 25
# 295       329 000 $       3 комнаты      2043 $ за м²         3 из 17
# 296        71 000 $       3 комнаты       710 $ за м²        17 из 35
# 297   1 885 431 грн       2 комнаты    *** not found   *** not found
# 298       980 000 $        5 комнат      4601 $ за м²        10 из 13
# 299        68 000 $       2 комнаты      1097 $ за м²          6 из 9
# 300        71 000 $       2 комнаты      1127 $ за м²         9 из 24
# 301       190 000 $       2 комнаты      2111 $ за м²        14 из 16
# 302   3 641 884 грн       1 комната    *** not found   *** not found
# 303       115 000 $       2 комнаты      1575 $ за м²        21 из 25
# 304        45 000 $       1 комната      1324 $ за м²        10 из 16
# 305        57 000 $       1 комната      1140 $ за м²        21 из 27
# 306        45 500 $       2 комнаты      1167 $ за м²          4 из 5
# 307       260 000 $       2 комнаты      4727 $ за м²         5 из 24
# 308        80 000 $       1 комната      1379 $ за м²        12 из 25
# 309   2 110 252 грн       1 комната    *** not found   *** not found
# 310       138 000 $       3 комнаты      1500 $ за м²         6 из 26
# 311       105 000 $       2 комнаты      1544 $ за м²         7 из 25
# 312   2 363 130 грн       2 комнаты  27 900 грн за м²        12 из 26
# 313        89 000 $       2 комнаты      1369 $ за м²        12 из 20
# 314       400 000 $       3 комнаты      2759 $ за м²        19 из 24
# 315       100 000 $       2 комнаты      1724 $ за м²         9 из 17
# 316        61 500 $       3 комнаты       809 $ за м²        14 из 16
# 317        48 000 $       1 комната      1043 $ за м²        18 из 24
# 318       180 000 $       2 комнаты      2045 $ за м²        23 из 25
# 319       108 000 €       3 комнаты      1158 € за м²         8 из 24
# 320        43 500 $       1 комната      1046 $ за м²        21 из 24
# 321       100 999 $       1 комната      1741 $ за м²         3 из 15
# 322        52 000 $       1 комната      1000 $ за м²        24 из 25
# 323       146 000 $       2 комнаты      2086 $ за м²        19 из 25
# 324       110 000 $       2 комнаты      1692 $ за м²         4 из 25
# 325       148 800 $       1 комната      3166 $ за м²         9 из 12
# 326        77 000 $       2 комнаты       975 $ за м²         3 из 25
# 327        38 500 $       1 комната      1132 $ за м²          5 из 9
# 328       100 000 $       3 комнаты      1020 $ за м²        16 из 26
# 329        78 000 $       1 комната      1560 $ за м²         4 из 22
# 330        75 000 $       2 комнаты      1071 $ за м²         3 из 25
# 331        45 000 $       2 комнаты      1000 $ за м²          1 из 5
# 332       900 000 $       3 комнаты      6000 $ за м²          9 из 9
# 333        85 000 $       2 комнаты      1288 $ за м²         2 из 22
# 334        65 600 $       2 комнаты      1009 $ за м²        22 из 26
# 335       395 000 $       3 комнаты      3038 $ за м²        11 из 28
# 336       155 000 $       2 комнаты      2214 $ за м²         9 из 10
# 337        84 000 $       2 комнаты      1400 $ за м²        14 из 24
# 338        73 000 $       3 комнаты       936 $ за м²          4 из 4
# 339        83 000 $       1 комната      1566 $ за м²        10 из 10
# 340       250 000 $       2 комнаты      3846 $ за м²          2 из 9
# 341       299 000 $       3 комнаты      3425 $ за м²          3 из 4
# 342        56 000 $       3 комнаты       812 $ за м²         9 из 10
# 343   4 335 178 грн       1 комната    *** not found   *** not found
# 344       270 000 $       2 комнаты      3333 $ за м²  *** not found
# 345        58 000 $       3 комнаты      1018 $ за м²          2 из 5
# 346        62 000 $       1 комната      1292 $ за м²        16 из 25
# 347        80 000 $       1 комната      1702 $ за м²         8 из 16
# 348       195 000 $       2 комнаты      2097 $ за м²          2 из 6
# 349   3 180 495 грн       1 комната    *** not found   *** not found
# 350       122 000 $       2 комнаты      1842 $ за м²          6 из 7
# 351   3 793 500 грн       3 комнаты  52 688 грн за м²        10 из 15
# 352        65 000 $       3 комнаты      1000 $ за м²          1 из 5
# 353        40 500 $       1 комната       827 $ за м²        26 из 26
# 354   1 181 731 грн       1 комната    *** not found   *** not found
# 355        69 000 $       1 комната      1683 $ за м²          6 из 9
# 356        75 000 $       2 комнаты      1415 $ за м²        20 из 22
# 357       155 000 $       2 комнаты      2013 $ за м²        12 из 21
# 358       220 000 $       2 комнаты      2200 $ за м²        15 из 25
# 359        51 500 $       2 комнаты       936 $ за м²        16 из 25
# 360        73 900 $       2 комнаты      1274 $ за м²         7 из 16
# 361   2 458 347 грн       1 комната    *** not found   *** not found
# 362     1 400 000 $        5 комнат      4487 $ за м²        28 из 30
# 363        93 950 $       3 комнаты      1080 $ за м²        16 из 17
# 364       395 000 $       4 комнаты      2724 $ за м²          7 из 9
# 365       179 000 $       1 комната      3580 $ за м²         7 из 23
# 366       260 000 $       2 комнаты      2080 $ за м²        11 из 17
# 367        52 000 $       1 комната      1209 $ за м²         6 из 25
# 368       395 000 $       3 комнаты      3038 $ за м²        11 из 28
# 369       198 450 $       2 комнаты      2450 $ за м²        12 из 24
# 370       750 000 $       3 комнаты      3606 $ за м²        15 из 23
# 371       650 000 $       4 комнаты      2124 $ за м²          4 из 8
# 372        75 000 $       1 комната      1389 $ за м²         6 из 25
# 373       150 000 $       3 комнаты      1429 $ за м²         4 из 24
# 374        93 900 $       2 комнаты      1361 $ за м²         8 из 26
# 375       120 500 $       1 комната      1826 $ за м²         6 из 10
# 376       129 000 $       2 комнаты      1925 $ за м²         5 из 25
# 377        62 000 $       1 комната      1348 $ за м²        18 из 19
# 378       150 000 $       3 комнаты      1442 $ за м²        16 из 17
# 379        55 000 $       1 комната      1000 $ за м²         5 из 24
# 380       138 000 $       3 комнаты      1500 $ за м²         6 из 26
# 381       172 000 $       3 комнаты      2000 $ за м²          7 из 9
# 382        79 900 $       3 комнаты       918 $ за м²        25 из 26
# 383        49 999 $       1 комната      1157 $ за м²        13 из 22
# 384       115 000 $       3 комнаты      1326 $ за м²        13 из 25
# 385        87 000 $       3 комнаты       958 $ за м²         2 из 25
# 386       107 000 $       1 комната      2202 $ за м²        16 из 24
# 387        87 700 $       2 комнаты      1015 $ за м²        19 из 24
# 388        65 000 $       2 комнаты      1275 $ за м²          9 из 9
# 389     1 250 000 $        5 комнат      5000 $ за м²          3 из 4
# 390        34 700 $       1 комната      1388 $ за м²          1 из 5
# 391        67 000 $       1 комната      1595 $ за м²         9 из 26
# 392        88 000 $       1 комната      1913 $ за м²          1 из 9
# 393       285 000 $       3 комнаты      2244 $ за м²        21 из 25
# 394        93 000 $       1 комната      2022 $ за м²        20 из 24
# 395        85 000 $       2 комнаты      1288 $ за м²        15 из 26
# 396       230 000 $       3 комнаты      1873 $ за м²         8 из 15
# 397       155 000 $       2 комнаты      2214 $ за м²         9 из 10
# 398       180 000 $       1 комната      2222 $ за м²         8 из 32
# 399        95 000 $       2 комнаты      1730 $ за м²        10 из 16
# 400        54 934 $       1 комната      1330 $ за м²          7 из 9
# 401       260 000 $       3 комнаты      3059 $ за м²         5 из 12
# 402       145 000 $       2 комнаты      1835 $ за м²        10 из 25
# 403       135 000 $       3 комнаты      1627 $ за м²          2 из 4
# 404        50 000 $       1 комната      1316 $ за м²        10 из 18
# 405       399 000 $       3 комнаты      2494 $ за м²          3 из 9
# 406        55 000 $       1 комната      1486 $ за м²          4 из 5
# 407       270 000 $        5 комнат      1362 $ за м²         7 из 16
# 408       337 000 $       3 комнаты      3120 $ за м²        12 из 27
# 409       170 000 $       4 комнаты      1133 $ за м²        16 из 17
# 410        85 000 $       3 комнаты      1181 $ за м²          4 из 9
# 411       279 000 $       4 комнаты      2131 $ за м²          5 из 5
# 412        44 000 $       1 комната      1073 $ за м²         8 из 26
# 413       170 000 $       1 комната      3208 $ за м²         4 из 26
# 414        88 000 $       1 комната      2047 $ за м²         3 из 24
# 415        41 500 $       2 комнаты       892 $ за м²          3 из 5
# 416        70 000 $       2 комнаты       986 $ за м²        11 из 25
# 417       119 900 $       2 комнаты      2141 $ за м²        18 из 24
# 418        86 000 $       3 комнаты       729 $ за м²        12 из 23
# 419       138 000 $       3 комнаты      1725 $ за м²        25 из 26
# 420       240 000 $       2 комнаты      2824 $ за м²          4 из 8
# 421       149 500 $       3 комнаты      1438 $ за м²        11 из 16
# 422   1 999 600 грн       1 комната  33 177 грн за м²          1 из 4
# 423        67 999 $       2 комнаты      1438 $ за м²          8 из 9
# 424        41 500 $       1 комната      1339 $ за м²          2 из 5
# 425        99 000 $       3 комнаты      1100 $ за м²        10 из 10
# 426       580 000 $       3 комнаты      5577 $ за м²        18 из 26
# 427        75 000 $       1 комната      1630 $ за м²         7 из 19
# 428       299 000 $       3 комнаты      2903 $ за м²         4 из 24
# 429        44 000 $       1 комната      1158 $ за м²        13 из 16
# 430       139 000 $       3 комнаты      1252 $ за м²        23 из 36
# 431       150 000 $       3 комнаты      1667 $ за м²        26 из 26
# 432        45 690 $       2 комнаты       819 $ за м²         9 из 16
# 433       115 000 $       2 комнаты      1456 $ за м²        13 из 17
# 434        63 500 $       3 комнаты       858 $ за м²         8 из 10
# 435        42 000 $       2 комнаты       913 $ за м²          9 из 9
# 436        56 500 $       2 комнаты      1153 $ за м²          1 из 9
# 437        66 000 $       2 комнаты       868 $ за м²         1 из 25
# 438       103 000 $       3 комнаты      1000 $ за м²        21 из 22
# 439        63 000 $       1 комната      1355 $ за м²        13 из 26
# 440       228 000 $       3 комнаты      2073 $ за м²         8 из 10
# 441        90 000 $       3 комнаты      1286 $ за м²         5 из 16
# 442        87 000 $       3 комнаты       915 $ за м²         9 из 19
# 443        62 000 $       3 комнаты      1033 $ за м²          1 из 9
# 444        77 000 $       3 комнаты       828 $ за м²         4 из 16
# 445       179 900 $       3 комнаты      1384 $ за м²        12 из 16
# 446        49 000 $       1 комната      1960 $ за м²          2 из 4
# 447       105 900 $       1 комната      1925 $ за м²        22 из 26
# 448       500 000 $       3 комнаты      2924 $ за м²          3 из 8
# 449        38 000 $       1 комната       884 $ за м²        15 из 25
# 450       130 000 $       1 комната      2708 $ за м²        16 из 24
# 451       230 000 $       3 комнаты      2644 $ за м²          4 из 9
# 452        66 800 $       2 комнаты      1260 $ за м²          4 из 9
# 453       125 000 $       2 комнаты      1488 $ за м²         2 из 12
# 454       113 000 $       2 комнаты      2457 $ за м²          2 из 5
# 455        93 000 $       1 комната      1788 $ за м²        10 из 15
# 456       422 000 $       2 комнаты      4637 $ за м²        13 из 15
# 457        80 500 $       2 комнаты      1238 $ за м²        26 из 13
# 458       123 000 $       2 комнаты      1500 $ за м²         6 из 26
# 459       200 000 $       3 комнаты      2273 $ за м²          3 из 7
# 460        52 000 $       2 комнаты      1268 $ за м²          5 из 5
# 461       360 000 $        5 комнат      2400 $ за м²          5 из 6
# 462       102 000 $       2 комнаты      1397 $ за м²        23 из 25
# 463        77 000 $       3 комнаты       951 $ за м²        18 из 26
# 464       125 000 $       1 комната      2500 $ за м²         6 из 25
# 465        84 000 $       1 комната      2270 $ за м²        10 из 16
# 466       185 000 $       1 комната      3083 $ за м²         3 из 30
# 467     888 189 грн       1 комната    *** not found   *** not found
# 468        45 142 $       2 комнаты       717 $ за м²         8 из 19
# 469       980 000 $        5 комнат      4601 $ за м²        10 из 13
# 470       180 000 $       2 комнаты      2442 $ за м²         6 из 17
# 471        40 000 $       2 комнаты       887 $ за м²          2 из 5
# 472       110 000 $       4 комнаты      1264 $ за м²         2 из 16
# 473   3 600 804 грн       2 комнаты    *** not found   *** not found
# 474       165 000 $       3 комнаты      1602 $ за м²         9 из 17
# 475        92 550 $       2 комнаты      1157 $ за м²        23 из 26
# 476        80 000 $       4 комнаты       879 $ за м²        25 из 26
# 477       115 000 $       2 комнаты      1797 $ за м²        24 из 25
# 478   4 335 178 грн       1 комната    *** not found   *** not found
# 479       155 000 $       2 комнаты      1649 $ за м²         7 из 25
# 480       220 000 $       3 комнаты      1982 $ за м²         4 из 17
# 481        95 000 $       2 комнаты      2065 $ за м²         3 из 24
# 482       115 000 $       1 комната      2875 $ за м²        15 из 24
# 483   1 750 000 грн       2 комнаты  25 000 грн за м²        10 из 24
# 484       240 000 $       3 комнаты      2857 $ за м²          4 из 5
# 485   1 158 740 грн       1 комната    *** not found   *** not found
# 486       170 000 $       3 комнаты      2125 $ за м²        11 из 24
# 487        93 000 $       3 комнаты      1329 $ за м²        10 из 10
# 488       145 000 $       2 комнаты      1058 $ за м²          1 из 3
# 489        47 211 $       1 комната       926 $ за м²         7 из 13
# 490        81 000 $       2 комнаты      1558 $ за м²        25 из 25
# 491       750 000 $        5 комнат      3024 $ за м²          8 из 9
# 492        84 950 $       1 комната      1634 $ за м²         7 из 25
# 493       190 000 $       2 комнаты      2568 $ за м²        23 из 25
# 494        85 000 $       1 комната       787 $ за м²          3 из 3
# 495       211 000 $       2 комнаты      1899 $ за м²        17 из 25
# 496       136 279 $       1 комната      1100 $ за м²        14 из 15
# 497        71 000 $       1 комната      1291 $ за м²        23 из 26
# 498        95 000 $       3 комнаты      1418 $ за м²          3 из 9
# 499       120 000 $       2 комнаты      1714 $ за м²        24 из 25
# 500       335 000 $       2 комнаты      3807 $ за м²        15 из 19
# 501        38 500 $       1 комната      1604 $ за м²          6 из 9
# 502        47 000 $       1 комната      1098 $ за м²        15 из 25
# 503       105 000 $       3 комнаты      1092 $ за м²         9 из 26
# 504       163 000 $       1 комната      3543 $ за м²        20 из 24
# 505     1 500 000 $       4 комнаты      6000 $ за м²        20 из 21
# 506        49 000 $       1 комната      1324 $ за м²        18 из 25
# 507       100 000 $       1 комната      1961 $ за м²         8 из 22
# 508       130 000 $       2 комнаты      2131 $ за м²        24 из 25
# 509   2 688 000 грн       3 комнаты  24 436 грн за м²        23 из 24
# 510        52 600 $       3 комнаты       822 $ за м²          4 из 5
# 511        39 000 $       2 комнаты      1215 $ за м²          1 из 5
# 512       110 000 $       3 комнаты      1000 $ за м²        13 из 18
# 513       135 000 $       2 комнаты      2647 $ за м²        23 из 34
# 514       139 860 $       2 комнаты      1998 $ за м²        14 из 24
# 515        70 000 $       2 комнаты      1556 $ за м²          4 из 9
# 516        95 000 $       2 комнаты      1280 $ за м²         4 из 10
# 517       155 000 $       2 комнаты      2214 $ за м²               1
# 518        56 850 $       1 комната      1384 $ за м²        13 из 19
# 519       140 000 $       3 комнаты      1750 $ за м²         9 из 25
# 520       110 000 $       2 комнаты      2750 $ за м²        15 из 26
# 521       145 000 $       2 комнаты      2685 $ за м²        18 из 24
# 522       280 000 $       3 комнаты      2857 $ за м²        22 из 23
# 523       270 000 $        5 комнат      1459 $ за м²        17 из 20
# 524        50 500 $       1 комната      1036 $ за м²        11 из 26
# 525        39 000 $       2 комнаты       534 $ за м²          3 из 5
# 526       490 000 $       3 комнаты      4455 $ за м²        11 из 25
# 527        34 988 $       1 комната       875 $ за м²         4 из 11
# 528       311 000 $        5 комнат      1885 $ за м²         4 из 15
# 529        65 000 $       3 комнаты       878 $ за м²          3 из 9
# 530       169 000 $       2 комнаты      2965 $ за м²         7 из 24
# 531        70 000 $       3 комнаты      1000 $ за м²          1 из 9
# 532       103 000 $       3 комнаты      1188 $ за м²        23 из 25
# 533       140 000 $       3 комнаты      1795 $ за м²         9 из 14
# 534       116 500 $       1 комната      1985 $ за м²        15 из 22
# 535       107 000 $       3 комнаты      1163 $ за м²        18 из 26
# 536        77 000 $       1 комната      1426 $ за м²        16 из 24
# 537       165 000 $       3 комнаты      1941 $ за м²         7 из 16
# 538       450 000 $       10 комнат      1286 $ за м²        25 из 25
# 539       195 000 $       3 комнаты      2434 $ за м²        25 из 34
# 540       480 000 $       4 комнаты      2824 $ за м²         7 из 12
# 541       120 000 $       2 комнаты      2500 $ за м²          9 из 9
# 542        58 000 $       2 комнаты      1055 $ за м²          1 из 9
# 543     1 500 000 $       4 комнаты      6522 $ за м²          2 из 5
# 544       345 700 $       3 комнаты      2220 $ за м²         8 из 11
# 545       126 000 $       2 комнаты      1544 $ за м²         4 из 25
# 546       158 000 $       2 комнаты      1732 $ за м²        24 из 25
# 547       206 315 $       3 комнаты      1715 $ за м²        13 из 16
# 548        33 000 $       1 комната      1138 $ за м²          4 из 9
# 549       250 000 $       2 комнаты      3731 $ за м²          2 из 6
# 550        63 500 $       2 комнаты       882 $ за м²        18 из 25
# 551   2 100 000 грн       2 комнаты  38 182 грн за м²          6 из 9
# 552   1 180 000 грн       1 комната  24 979 грн за м²        17 из 26
# 553        42 000 $       1 комната       852 $ за м²        11 из 25
# 554       146 000 $       2 комнаты      2355 $ за м²         9 из 24
# 555       299 000 $       3 комнаты      2300 $ за м²        23 из 25
# 556       141 000 $       3 комнаты      2104 $ за м²          4 из 4
# 557        41 000 $       1 комната       976 $ за м²        15 из 26
# 558       115 000 $       3 комнаты      1554 $ за м²         6 из 12
# 559        81 000 $       3 комнаты       920 $ за м²        21 из 22
# 560       103 950 $       1 комната      2121 $ за м²        10 из 19
# 561   1 468 067 грн       1 комната  34 954 грн за м²         8 из 25
# 562        68 000 $       1 комната      1388 $ за м²        10 из 16
# 563        80 000 $       2 комнаты      1455 $ за м²          5 из 8
# 564       112 000 $       1 комната      2667 $ за м²         6 из 25
# 565       319 000 $       3 комнаты      2246 $ за м²         4 из 18
# 566        98 000 $       1 комната      1960 $ за м²         3 из 10
# 567        50 000 $       1 комната      1562 $ за м²          9 из 9
# 568        49 990 $       1 комната      1136 $ за м²        24 из 26
# 569        89 500 $       2 комнаты      1721 $ за м²          5 из 9
# 570       350 000 $       3 комнаты      2244 $ за м²         9 из 11
# 571       210 000 $       2 комнаты      1707 $ за м²        17 из 24
# 572       345 000 $       3 комнаты      2091 $ за м²        17 из 24
# 573        90 000 $       1 комната      1364 $ за м²        20 из 20
# 574       170 000 $       3 комнаты      2068 $ за м²          4 из 5
# 575       110 000 $       1 комната      2683 $ за м²        22 из 25
# 576        59 000 $       2 комнаты      1405 $ за м²          3 из 9
# 577       145 000 $       3 комнаты      2377 $ за м²          1 из 9
# 578        79 000 $       2 комнаты       988 $ за м²        28 из 28
# 579       375 000 $       3 комнаты      3151 $ за м²  *** not found
# 580       122 000 $       1 комната      2302 $ за м²         5 из 12
# 581       255 000 $       2 комнаты      4048 $ за м²        12 из 19
# 582        85 000 $       2 комнаты      1977 $ за м²          5 из 5
# 583       240 800 $       2 комнаты      2800 $ за м²         8 из 27
# 584       455 000 $       3 комнаты      3792 $ за м²  *** not found
# 585       165 000 $       3 комнаты      1528 $ за м²         7 из 10
# 586       100 000 $       3 комнаты      1064 $ за м²         3 из 25
# 587       195 000 $       3 комнаты      1696 $ за м²        20 из 24
# 588        41 000 $       1 комната      1131 $ за м²        14 из 26
# 589        70 000 $       2 комнаты      1273 $ за м²          2 из 3
# 590        71 400 $       2 комнаты      1152 $ за м²        13 из 26
# 591   3 711 865 грн       1 комната    *** not found   *** not found
# 592        60 000 $       3 комнаты      1237 $ за м²          3 из 3
# 593       240 000 $       3 комнаты      1967 $ за м²        22 из 30
# 594       260 000 $       3 комнаты      2889 $ за м²         4 из 14
# 595       127 000 $       2 комнаты      2309 $ за м²          7 из 9
# 596        40 000 $       1 комната      1000 $ за м²        11 из 16
# 597   1 796 439 грн       1 комната    *** not found   *** not found
# 598     3 400 000 $        5 комнат    10 000 $ за м²  *** not found
# 599        44 500 $       1 комната      1085 $ за м²         2 из 25
# 600       125 000 $       2 комнаты      2660 $ за м²          3 из 5
# 601        51 000 $       3 комнаты       927 $ за м²          9 из 9
# 602   1 707 790 грн       2 комнаты    *** not found   *** not found
# 603        65 000 $       2 комнаты      1000 $ за м²         7 из 20
# 604        55 000 $       1 комната      1719 $ за м²        17 из 25
# 605        94 500 $       2 комнаты      1500 $ за м²          1 из 8
# 606       115 000 $       1 комната      2300 $ за м²        15 из 25
# 607        45 000 $       1 комната      1250 $ за м²        11 из 26
# 608        85 000 $       1 комната      2429 $ за м²          9 из 9
# 609   5 204 750 грн       1 комната    *** not found   *** not found
# 610        84 500 $       1 комната      1690 $ за м²        21 из 25
# 611       350 000 $       3 комнаты      2121 $ за м²         7 из 15
# 612       182 000 $       2 комнаты      2563 $ за м²        28 из 34
# 613       188 999 $       3 комнаты      1718 $ за м²         4 из 19
# 614       147 000 $       3 комнаты      1441 $ за м²          4 из 8
# 615        89 900 $       3 комнаты      1124 $ за м²        24 из 25
# 616        66 900 $       3 комнаты      1115 $ за м²          5 из 9
# 617        75 000 $       2 комнаты      1071 $ за м²         3 из 25
# 618        58 000 $       4 комнаты       725 $ за м²          1 из 9
# 619       140 000 $       3 комнаты      1667 $ за м²         7 из 10
# 620        82 000 $       3 комнаты      1139 $ за м²        10 из 16
# 621       215 000 $       2 комнаты      2240 $ за м²        10 из 25
# 622        33 400 $       1 комната      1044 $ за м²          1 из 5
# 623       100 000 $       4 комнаты       885 $ за м²         4 из 14
# 624       240 000 $       3 комнаты      2017 $ за м²         5 из 25
# 625        62 000 $       2 комнаты      1016 $ за м²        23 из 25
# 626       115 000 $       2 комнаты      1533 $ за м²        18 из 25
# 627       143 560 $       1 комната      2618 $ за м²         9 из 30
# 628       130 000 $       3 комнаты      1585 $ за м²          4 из 6
# 629       152 000 $       3 комнаты      1551 $ за м²         7 из 20
# 630        33 800 $       1 комната      1056 $ за м²          3 из 5
# 631        55 000 $       1 комната      1486 $ за м²         2 из 25
# 632       110 000 $       3 комнаты      1146 $ за м²        16 из 22
# 633       200 000 $       2 комнаты      2703 $ за м²        12 из 14
# 634        70 000 $       2 комнаты      1296 $ за м²         4 из 26
# 635       160 888 $       3 комнаты      1828 $ за м²          5 из 5
# 636       189 000 $       3 комнаты      1510 $ за м²         3 из 18
# 637       135 000 $       2 комнаты      2077 $ за м²        16 из 23
# 638       215 000 $       2 комнаты      4300 $ за м²          3 из 3
# 639       102 000 $       3 комнаты      1020 $ за м²        10 из 10
# 640       193 750 $       3 комнаты      1550 $ за м²        22 из 22
# 641        54 000 $       1 комната       982 $ за м²        10 из 25
# 642        70 000 $       2 комнаты      1273 $ за м²          4 из 5
# 643   3 180 495 грн       1 комната    *** not found   *** not found
# 644        50 500 $       1 комната       973 $ за м²        18 из 25
# 645        57 000 $       3 комнаты      1036 $ за м²          1 из 5
# 646       130 000 $       2 комнаты      2152 $ за м²          1 из 5
# 647       262 000 $       3 комнаты      2015 $ за м²         6 из 17
# 648        66 000 $       1 комната      1650 $ за м²        12 из 16
# 649   3 249 056 грн       1 комната    *** not found   *** not found
# 650   2 000 000 грн       2 комнаты  26 667 грн за м²         8 из 26
# 651        78 000 $       4 комнаты       796 $ за м²          2 из 9
# 652        90 500 $       1 комната      1550 $ за м²        17 из 21
# 653        80 000 $       2 комнаты      1569 $ за м²          6 из 9
# 654     906 080 грн       1 комната    *** not found   *** not found
# 655     4 500 000 $       4 комнаты    14 610 $ за м²        18 из 21
# ...
# 756           44 / 17 / 14 м²                                  ул. Причальная
# 757       64.8 / 17.2 / 15 м²                          ул. Бойчука (Киквидзе)
# 758           41 / 18 / 14 м²                                    ул. Радистов
# 759            51 / 31 / 8 м²                                ул. Лукьяновская
# 760           55 / 16 / 20 м²                                   просп. Правды
# 761                     81 м²                  ул. Шевелёва (Николая Руднева)
# 762           82 / 42 / 15 м²                       просп. Героев Сталинграда
# 763            89 / 70 / 8 м²             ул. Ефремова (Уборевича Командарма)
# 764         44.3 / 18 / 11 м²                                 Балтийский пер.
# 765           44 / 20 / 13 м²                          ул. Бойчука (Киквидзе)
# 766     358 / 192.8 / 19.7 м²         ул. Ивана Мазепы (Январского восстания)
# 767           95 / 46 / 13 м²                                      ул. Гришко
# 768            68 / 47 / 8 м²                              ул. Семьи Сосниных
# 769          112 / 52 / 25 м²                                  Харьковское ш.
# 770                     38 м²                                 ул. Будищанская
# 771                     44 м²                               МФК Intergal City
# 772      72.4 / 42.9 / 6.4 м²                                   ул. Мечникова
# 773           40 / 15 / 14 м²                                Днепровская наб.
# 774          70 / 51 / 8.5 м²                              просп. Маяковского
# 775   57.51 / 40.05 / 6.98 м²                                     ул. Гончара
# 776           63 / 25 / 20 м²               ул. И. Павла ІІ (Патриса Лумумбы)
# 777                     42 м²                            ЖК Rusaniv Residence
# 778          120 / 80 / 15 м²                       просп. Героев Сталинграда
# 779                    120 м²                                 ул. Драгомирова
# 780                     70 м²                                 ул. Драгомирова
# 781         160 / 100 / 25 м²                       просп. Героев Сталинграда
# 782                     53 м²                                 ЖК Olympic Park
# 783                    222 м²                                 ул. Драгомирова
# 784                    104 м²                                пл. Бессарабская
# 785           44 / 25 / 15 м²                                  ул. Ломоносова
# 786           47 / 20 / 12 м²                               ул. Тираспольская
# 787       200.3 / 180 / 20 м²                                      ул. Франко
# 788           72 / 13 / 41 м²                                 ул. Шелковичная
# 789                     31 м²                                 ЖК Берег Днепра
# 790           66 / 35 / 12 м²          просп. Голосеевский (40-летия Октября)
# 791          120 / 67 / 15 м²                                  ул. Ломоносова
# 792           95 / 35 / 38 м²                       просп. Героев Сталинграда
# 793          112 / 70 / 35 м²                              ул. Регенераторная
# 794           50 / 21 / 16 м²                                    ул. Салютная
# 795          126 / 70 / 15 м²                               ул. Саперное Поле
#
#             8
# 0          4в
# 1         NaN
# 2        150в
# 3          36
# 4         71д
# 5         18а
# 6          74
# 7         14б
# 8          53
# 9         16б
# 10         12
# 11        NaN
# 12        40г
# 13         8а
# 14        12б
# 15         6а
# 16          3
# 17        NaN
# 18          5
# 19        NaN
# 20         4б
# 21        37а
# 22         53
# 23          8
# 24        23б
# 25        25а
# 26        NaN
# 27        NaN
# 28         26
# 29          3
# 30        NaN
# 31        NaN
# 32         7в
# 33        NaN
# 34        NaN
# 35        125
# 36         7в
# 37        NaN
# 38        NaN
# 39        16в
# 40          8
# 41        16г
# 42         5б
# 43        NaN
# 44        41д
# 45        39а
# 46        NaN
# 47        16ж
# 48        32а
# 49         10
# 50         44
# 51        NaN
# 52         57
# 53         1а
# 54         12
# 55          7
# 56          8
# 57         62
# 58         83
# 59        NaN
# 60         16
# 61         45
# 62         77
# 63         72
# 64         7б
# 65          7
# 66        NaN
# 67        NaN
# 68         22
# 69         26
# 70         27
# 71         60
# 72        32а
# 73         10
# 74         44
# 75        NaN
# 76         57
# 77         1а
# 78         12
# 79          7
# 80          8
# 81         62
# 82         83
# 83        NaN
# 84         16
# 85         45
# 86         77
# 87         72
# 88         7б
# 89          7
# 90        NaN
# 91        NaN
# 92         22
# 93         26
# 94         27
# 95         60
# 96         47
# 97      4/39а
# 98         20
# 99        27в
# 100       NaN
# 101       68а
# 102        45
# 103        60
# 104       NaN
# 105        41
# 106       NaN
# 107       NaN
# 108       NaN
# 109       13г
# 110       31а
# 111       2к2
# 112        97
# 113       NaN
# 114        35
# 115       NaN
# 116        2а
# 117       NaN
# 118       NaN
# 119       NaN
# 120         3
# 121     11/12
# 122        18
# 123         3
# 124        5б
# 125        16
# 126         6
# 127       NaN
# 128       NaN
# 129       NaN
# 130       4к4
# 131        14
# 132       NaN
# 133      1/36
# 134         6
# 135        2д
# 136       NaN
# 137        43
# 138        26
# 139       NaN
# 140       36е
# 141         4
# 142        14
# 143       NaN
# 144         6
# 145        14
# 146       NaN
# 147        11
# 148        15
# 149         4
# 150       NaN
# 151       NaN
# 152       16б
# 153       NaN
# 154       40а
# 155        31
# 156       95а
# 157         3
# 158       NaN
# 159       NaN
# 160         5
# 161     18/30
# 162       NaN
# 163       NaN
# 164       NaN
# 165       NaN
# 166        30
# 167     28-30
# 168         7
# 169       32а
# 170   28а/30а
# 171        60
# 172        54
# 173       NaN
# 174       NaN
# 175       34а
# 176       NaN
# 177        6а
# 178       23а
# 179         7
# 180       30б
# 181         1
# 182        17
# 183        57
# 184       37б
# 185         8
# 186         8
# 187       23а
# 188        1в
# 189        4в
# 190       NaN
# 191        38
# 192        11
# 193     14/55
# 194       NaN
# 195       NaN
# 196         2
# 197        40
# 198         7
# 199       28б
# 200       NaN
# 201         5
# 202       26а
# 203        11
# 204       NaN
# 205      131а
# 206       NaN
# 207       20б
# 208        17
# 209       43а
# 210        4в
# 211       NaN
# 212       NaN
# 213        17
# 214       NaN
# 215       NaN
# 216       18г
# 217       15а
# 218       NaN
# 219        34
# 220       NaN
# 221      174б
# 222       10а
# 223      109а
# 224       83а
# 225       NaN
# 226        1б
# 227        49
# 228       15а
# 229         4
# 230       NaN
# 231         1
# 232        4б
# 233       NaN
# 234       2к2
# 235       93а
# 236      10/1
# 237         3
# 238       NaN
# 239         6
# 240         2
# 241       NaN
# 242        59
# 243       15а
# 244        2б
# 245       NaN
# 246        1б
# 247        1б
# 248       NaN
# 249       11а
# 250       NaN
# 251        70
# 252     46/11
# 253        35
# 254        3а
# 255         9
# 256         6
# 257     18/20
# 258       NaN
# 259        34
# 260        7б
# 261     51/1а
# 262         1
# 263        17
# 264       NaN
# 265       1к1
# 266       NaN
# 267       NaN
# 268         3
# 269       NaN
# 270       NaN
# 271        42
# 272       NaN
# 273       NaN
# 274       NaN
# 275        3а
# 276       NaN
# 277       NaN
# 278        9а
# 279       NaN
# 280       NaN
# 281       73д
# 282        52
# 283         5
# 284       16д
# 285         7
# 286         9
# 287       NaN
# 288        40
# 289        15
# 290         2
# 291       NaN
# 292       NaN
# 293       17а
# 294       NaN
# 295        39
# 296       NaN
# 297       NaN
# 298        14
# 299         8
# 300       NaN
# 301         6
# 302       NaN
# 303        4в
# 304        22
# 305       NaN
# 306       19а
# 307        2а
# 308       NaN
# 309       NaN
# 310       37б
# 311        2б
# 312       NaN
# 313      55/2
# 314        4в
# 315      60/5
# 316        77
# 317       NaN
# 318        8в
# 319        22
# 320       NaN
# 321         6
# 322       NaN
# 323      10/1
# 324       12б
# 325        12
# 326        11
# 327       10а
# 328         7
# 329        2в
# 330         8
# 331       12г
# 332         5
# 333        13
# 334       NaN
# 335       NaN
# 336        4в
# 337       NaN
# 338       NaN
# 339        75
# 340        35
# 341         9
# 342         5
# 343       NaN
# 344         3
# 345        53
# 346         3
# 347       NaN
# 348        9б
# 349       NaN
# 350       NaN
# 351     91/14
# 352        13
# 353       NaN
# 354       NaN
# 355       NaN
# 356       NaN
# 357        40
# 358       44а
# 359       NaN
# 360        25
# 361       NaN
# 362        11
# 363        32
# 364       NaN
# 365         7
# 366        13
# 367       NaN
# 368       NaN
# 369         3
# 370        13
# 371         8
# 372       26а
# 373        6г
# 374       NaN
# 375     26/41
# 376      50/2
# 377         3
# 378        24
# 379       NaN
# 380       37б
# 381         8
# 382        60
# 383        95
# 384         6
# 385       NaN
# 386        8а
# 387       NaN
# 388        16
# 389      6/11
# 390       10в
# 391        15
# 392       NaN
# 393       13а
# 394       NaN
# 395       NaN
# 396       26а
# 397        4в
# 398       37К
# 399       40а
# 400       20а
# 401       NaN
# 402        89
# 403       34а
# 404       NaN
# 405     30/39
# 406       NaN
# 407        18
# 408         7
# 409         6
# 410        6а
# 411      24/7
# 412       41а
# 413       32в
# 414       NaN
# 415         7
# 416       190
# 417       NaN
# 418       26з
# 419       14д
# 420        19
# 421        27
# 422       NaN
# 423       NaN
# 424        12
# 425        4д
# 426       1/2
# 427      55/2
# 428         7
# 429         9
# 430         1
# 431       15а
# 432       NaN
# 433       3/5
# 434       NaN
# 435        11
# 436        4а
# 437        13
# 438        11
# 439       16г
# 440       NaN
# 441       36б
# 442       14а
# 443        19
# 444       31б
# 445        22
# 446         2
# 447       35а
# 448     46/11
# 449       NaN
# 450        6а
# 451        10
# 452        19
# 453       NaN
# 454        31
# 455        13
# 456         3
# 457       NaN
# 458       NaN
# 459        21
# 460       22б
# 461         9
# 462         2
# 463        60
# 464       NaN
# 465       NaN
# 466        17
# 467       NaN
# 468       NaN
# 469        14
# 470       30в
# 471        12
# 472        9б
# 473       NaN
# 474        3а
# 475       NaN
# 476       NaN
# 477        10
# 478       NaN
# 479       NaN
# 480     45а/3
# 481        35
# 482        57
# 483       NaN
# 484      2/21
# 485       NaN
# 486       33а
# 487    85/87а
# 488       NaN
# 489         6
# 490        2а
# 491        80
# 492         2
# 493         6
# 494       NaN
# 495       NaN
# 496       NaN
# 497       NaN
# 498         2
# 499        4а
# 500         3
# 501     55/13
# 502       NaN
# 503       NaN
# 504        44
# 505         2
# 506        60
# 507        2а
# 508       37б
# 509        3в
# 510       NaN
# 511        7б
# 512        31
# 513        5в
# 514       121
# 515       16а
# 516       34г
# 517         8
# 518       NaN
# 519      121б
# 520       16г
# 521       44а
# 522        14
# 523       NaN
# 524       NaN
# 525       NaN
# 526       20а
# 527       NaN
# 528        39
# 529        24
# 530        11
# 531       16а
# 532         6
# 533        20
# 534        42
# 535        22
# 536        2б
# 537      67к2
# 538       NaN
# 539        5в
# 540        72
# 541        24
# 542        27
# 543         5
# 544       NaN
# 545       NaN
# 546       13б
# 547        48
# 548        17
# 549        19
# 550       NaN
# 551         4
# 552       NaN
# 553       NaN
# 554       NaN
# 555       32г
# 556       123
# 557       NaN
# 558         4
# 559       190
# 560       75а
# 561       NaN
# 562       21а
# 563        34
# 564         1
# 565        4в
# 566         2
# 567        37
# 568       NaN
# 569       6/8
# 570       NaN
# 571       NaN
# 572        2а
# 573        13
# 574        43
# 575       NaN
# 576        39
# 577         3
# 578       15а
# 579         7
# 580        27
# 581         2
# 582         3
# 583        26
# 584        20
# 585        37
# 586       NaN
# 587       19в
# 588       NaN
# 589        28
# 590       NaN
# 591       NaN
# 592       NaN
# 593       1к1
# 594       29а
# 595         3
# 596       NaN
# 597       NaN
# 598       26а
# 599       NaN
# 600         9
# 601        11
# 602       NaN
# 603        24
# 604         6
# 605        34
# 606        1а
# 607       NaN
# 608        16
# 609       NaN
# 610       NaN
# 611         4
# 612        5в
# 613      46/1
# 614         8
# 615       NaN
# 616        6а
# 617         8
# 618        34
# 619       NaN
# 620       16в
# 621       32г
# 622      2/26
# 623        9в
# 624        13
# 625        24
# 626        30
# 627       NaN
# 628       NaN
# 629         7
# 630         3
# 631       NaN
# 632        20
# 633        53
# 634       NaN
# 635         7
# 636       NaN
# 637       14б
# 638        11
# 639         5
# 640      6/7а
# 641       NaN
# 642         4
# 643       NaN
# 644       NaN
# 645         9
# 646     14/26
# 647        13
# 648        58
# 649       NaN
# 650       27а
# 651        17
# 652       NaN
# 653        26
# 654       NaN
# 655       11б
# 656       NaN
# 657         6
# 658      10/1
# 659       NaN
# 660        60
# 661       NaN
# 662         2
# 663        39
# 664        3в
# 665        48
# 666        40
# 667       32а
# 668       19а
# 669       NaN
# 670       NaN
# 671        26
# 672        18
# 673       6/2
# 674       NaN
# 675       1к1
# 676       2к2
# 677         8
# 678       45а
# 679         5
# 680         7
# 681       NaN
# 682      168е
# 683        43
# 684      116а
# 685        26
# 686        2г
# 687      6/7а
# 688      37/1
# 689       NaN
# 690      44/2
# 691      6/7а
# 692         6
# 693       NaN
# 694        17
# 695       NaN
# 696       NaN
# 697       NaN
# 698        3а
# 699       NaN
# 700         2
# 701       NaN
# 702       37б
# 703       40д
# 704       NaN
# 705      60/5
# 706       NaN
# 707       16д
# 708         4
# 709         2
# 710       73г
# 711       45а
# 712        3а
# 713       NaN
# 714       NaN
# 715        19
# 716       NaN
# 717     20/22
# 718         2
# 719       28а
# 720         6
# 721       NaN
# 722       19а
# 723       NaN
# 724       16ж
# 725        4а
# 726       NaN
# 727       NaN
# 728      3/12
# 729        7в
# 730         2
# 731       NaN
# 732     47-49
# 733         7
# 734        32
# 735        4а
# 736       NaN
# 737       NaN
# 738        27
# 739       NaN
# 740     11/39
# 741      37/1
# 742       20в
# 743       NaN
# 744       NaN
# 745       NaN
# 746        11
# 747        59
# 748       NaN
# 749        57
# 750         3
# 751        13
# 752       NaN
# 753     30/51
# 754       NaN
# 755       NaN
# 756       NaN
# 757       NaN
# 758        34
# 759        27
# 760       NaN
# 761     49/20
# 762        4а
# 763        21
# 764       NaN
# 765       NaN
# 766       11б
# 767         9
# 768       NaN
# 769        56
# 770         6
# 771       NaN
# 772       1/4
# 773       NaN
# 774       21а
# 775       NaN
# 776       NaN
# 777       NaN
# 778       12г
# 779         7
# 780        11
# 781       24а
# 782       NaN
# 783       NaN
# 784         5
# 785      46/1
# 786       NaN
# 787        4б
# 788        48
# 789       NaN
# 790       NaN
# 791       73в
# 792     64/56
# 793       4к5
# 794       NaN
# 795     14/55
